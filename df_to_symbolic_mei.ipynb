# %%
from py_scripts.mei import process_and_visualize
import pandas as pd

peaks_df = pd.read_csv('tsv/noanoa_single.tsv', delimiter='\t')

process_and_visualize(peaks_df, resolution='half_tone_deviation', include_natural_accidentals=False, save_mei=False, save_path='my_output.mei', display_df=True)
#
# Out:
#     Frequency (Hz)  MIDI Value MIDI Cent Deviation Pitch Name Note  Octave  \
# 0       173.333333          53                 -13         F3    F       3
# 1       182.666667          54                 -22        F#3    F       3
# 2       190.666667          55                 -48         G3    G       3
# 3       201.333333          55                 +46         G3    G       3
# 4       208.000000          56                  +3        G#3    G       3
# ..             ...         ...                 ...        ...  ...     ...
# 60     2904.000000         102                 -33        F#7    F       7
# 61     2920.000000         102                 -24        F#7    F       7
# 62     4330.666667         109                 -41        C#8    C       8
# 63     4337.333333         109                 -39        C#8    C       8
# 64     6010.666667         114                 +26        F#8    F       8
#
#    Alter
# 0      n
# 1      s
# 2      n
# 3      n
# 4      s
# ...
