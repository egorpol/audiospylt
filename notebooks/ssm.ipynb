# %%
from audiospylt.ssm import run_notebook

# Local path OR URL (http(s)://...)
result = run_notebook(
    "C:/Users/egorp/Nextcloud/code/playground/chant1.wav",
    resample=False,
    custom_sr=44100,
    analysis_method="chroma",  # "chroma" | "mfcc" | "chroma+mfcc"
    window_sec=1.0,
    mfcc_start=0,
    mfcc_end=20,  # exclusive (0..19)
    diagonal_smooth_width=5,
)

# Optional: access the matrix
# ssm_matrix = None if result is None else result["ssm"]
# Out:
# Analysis Parameters:
#   wav_source: C:/Users/egorp/Nextcloud/code/playground/chant1.wav
#   resample: False
#   custom_sr: 44100
#   analysis_method: chroma
#   window_sec: 1.0
#   mfcc_start: 0
#   mfcc_end: 20
#   diagonal_smooth_width: 5
# ------------------------------
# WAV file loaded from local path: C:\Users\egorp\Nextcloud\code\playground\chant1.wav
# Number of audio channels: 1
# Sampling rate: 44100 Hz
# WAV file loaded from C:/Users/egorp/Nextcloud/code/playground/chant1.wav
# Computing chromagram (full signal)...
